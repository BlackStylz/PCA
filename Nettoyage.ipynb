# %% [markdown]
# # Nettoyage

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import re
import warnings

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from numpy import isnan

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# #### Message d'avertissements

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Dimension des dataframes

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# #### Import CSV Data

# %%
data = pd.read_csv("./Data/en1.openfoodfacts.org.products.csv", sep='\t')
data.shape
# Out:
# (253678, 197)

# %% [markdown]
# ## Préparation des données

# %% [markdown]
# #### Vérification des doubles

# %%
data.loc[data.duplicated(keep=False)].shape
# Out:
# (0, 197)

# %%
data.loc[data["product_name"].duplicated(keep=False)].shape
# Out:
# (77602, 197)

# %% [markdown]
# #### Format des colonnes

# %%
data.shape
# Out:
# (253678, 197)

# %%
data_b = data.copy()

# %%
for n in data_b.columns:
    i = re.search("_datetime$",n)
    t =  re.search("_t$",n)
    if i:
        data_b[n] = pd.to_datetime(data_b[n], errors='coerce')
    if t:
        data_b[n] = pd.to_datetime(data_b[n], errors='coerce', unit='s')
        
data_b.dtypes
# Out:
# Unnamed: 0                                                             int64
# code                                                                  object
# url                                                                   object
# creator                                                               object
# created_t                                                     datetime64[ns]
# created_datetime                                         datetime64[ns, UTC]
# last_modified_t                                               datetime64[ns]
# last_modified_datetime                                   datetime64[ns, UTC]
# product_name                                                          object
# abbreviated_product_name                                              object
# generic_name                                                          object
# quantity                                                              object
# packaging                                                             object
# packaging_tags                                                        object
# packaging_en                                                          object
# packaging_text                                                        object
# brands                                                                object
# brands_tags                                                           object
# categories                                                            object
# categories_tags                                                       object
# categories_en                                                         object
# origins                                                               object
# origins_tags                                                          object
# origins_en                                                            object
# manufacturing_places                                                  object
# manufacturing_places_tags                                             object
# labels                                                                object
# labels_tags                                                           object
# labels_en                                                             object
# emb_codes                                                             object
# emb_codes_tags                                                        object
# first_packaging_code_geo                                              object
# cities                                                               float64
# cities_tags                                                           object
# purchase_places                                                       object
# stores                                                                object
# countries                                                             object
# countries_tags                                                        object
# countries_en                                                          object
# ingredients_text                                                      object
# ingredients_tags                                                      object
# ingredients_analysis_tags                                             object
# allergens                                                             object
# allergens_en                                                         float64
# traces                                                                object
# traces_tags                                                           object
# traces_en                                                             object
# serving_size                                                          object
# serving_quantity                                                     float64
# no_nutriments                                                        float64
# additives_n                                                          float64
# additives                                                            float64
# additives_tags                                                        object
# additives_en                                                          object
# nutriscore_score                                                     float64
# nutriscore_grade                                                      object
# nova_group                                                           float64
# pnns_groups_1                                                         object
# pnns_groups_2                                                         object
# food_groups                                                           object
# food_groups_tags                                                      object
# food_groups_en                                                        object
# states                                                                object
# states_tags                                                           object
# states_en                                                             object
# brand_owner                                                           object
# ecoscore_score                                                       float64
# ecoscore_grade                                                        object
# nutrient_levels_tags                                                  object
# product_quantity                                                     float64
# owner                                                                 object
# data_quality_errors_tags                                              object
# unique_scans_n                                                       float64
# popularity_tags                                                       object
# completeness                                                         float64
# last_image_t                                                  datetime64[ns]
# last_image_datetime                                      datetime64[ns, UTC]
# main_category                                                         object
# main_category_en                                                      object
# image_url                                                             object
# image_small_url                                                       object
# image_ingredients_url                                                 object
# image_ingredients_small_url                                           object
# image_nutrition_url                                                   object
# image_nutrition_small_url                                             object
# energy-kj_100g                                                       float64
# energy-kcal_100g                                                     float64
# energy_100g                                                          float64
# energy-from-fat_100g                                                 float64
# fat_100g                                                             float64
# saturated-fat_100g                                                   float64
# -butyric-acid_100g                                                   float64
# -caproic-acid_100g                                                   float64
# -caprylic-acid_100g                                                  float64
# -capric-acid_100g                                                    float64
# -lauric-acid_100g                                                    float64
# -myristic-acid_100g                                                  float64
# -palmitic-acid_100g                                                  float64
# -stearic-acid_100g                                                   float64
# -arachidic-acid_100g                                                 float64
# -behenic-acid_100g                                                   float64
# -lignoceric-acid_100g                                                float64
# -cerotic-acid_100g                                                   float64
# -montanic-acid_100g                                                  float64
# -melissic-acid_100g                                                  float64
# monounsaturated-fat_100g                                             float64
# polyunsaturated-fat_100g                                             float64
# omega-3-fat_100g                                                     float64
# -alpha-linolenic-acid_100g                                           float64
# -eicosapentaenoic-acid_100g                                          float64
# -docosahexaenoic-acid_100g                                           float64
# omega-6-fat_100g                                                     float64
# -linoleic-acid_100g                                                  float64
# -arachidonic-acid_100g                                               float64
# -gamma-linolenic-acid_100g                                           float64
# -dihomo-gamma-linolenic-acid_100g                                    float64
# omega-9-fat_100g                                                     float64
# -oleic-acid_100g                                                     float64
# -elaidic-acid_100g                                                   float64
# -gondoic-acid_100g                                                   float64
# -mead-acid_100g                                                      float64
# -erucic-acid_100g                                                    float64
# -nervonic-acid_100g                                                  float64
# trans-fat_100g                                                       float64
# cholesterol_100g                                                     float64
# carbohydrates_100g                                                   float64
# sugars_100g                                                          float64
# -sucrose_100g                                                        float64
# -glucose_100g                                                        float64
# -fructose_100g                                                       float64
# -lactose_100g                                                        float64
# -maltose_100g                                                        float64
# -maltodextrins_100g                                                  float64
# starch_100g                                                          float64
# polyols_100g                                                         float64
# fiber_100g                                                           float64
# soluble-fiber_100g                                                   float64
# insoluble-fiber_100g                                                 float64
# proteins_100g                                                        float64
# casein_100g                                                          float64
# serum-proteins_100g                                                  float64
# nucleotides_100g                                                     float64
# salt_100g                                                            float64
# sodium_100g                                                          float64
# alcohol_100g                                                         float64
# vitamin-a_100g                                                       float64
# beta-carotene_100g                                                   float64
# vitamin-d_100g                                                       float64
# vitamin-e_100g                                                       float64
# vitamin-k_100g                                                       float64
# vitamin-c_100g                                                       float64
# vitamin-b1_100g                                                      float64
# vitamin-b2_100g                                                      float64
# vitamin-pp_100g                                                      float64
# vitamin-b6_100g                                                      float64
# vitamin-b9_100g                                                      float64
# folates_100g                                                         float64
# vitamin-b12_100g                                                     float64
# biotin_100g                                                          float64
# pantothenic-acid_100g                                                float64
# silica_100g                                                          float64
# bicarbonate_100g                                                     float64
# potassium_100g                                                       float64
# chloride_100g                                                        float64
# calcium_100g                                                         float64
# phosphorus_100g                                                      float64
# iron_100g                                                            float64
# magnesium_100g                                                       float64
# zinc_100g                                                            float64
# copper_100g                                                          float64
# manganese_100g                                                       float64
# fluoride_100g                                                        float64
# selenium_100g                                                        float64
# chromium_100g                                                        float64
# molybdenum_100g                                                      float64
# iodine_100g                                                          float64
# caffeine_100g                                                        float64
# taurine_100g                                                         float64
# ph_100g                                                              float64
# fruits-vegetables-nuts_100g                                          float64
# fruits-vegetables-nuts-dried_100g                                    float64
# fruits-vegetables-nuts-estimate_100g                                 float64
# fruits-vegetables-nuts-estimate-from-ingredients_100g                float64
# collagen-meat-protein-ratio_100g                                     float64
# cocoa_100g                                                           float64
# chlorophyl_100g                                                      float64
# carbon-footprint_100g                                                float64
# carbon-footprint-from-meat-or-fish_100g                              float64
# nutrition-score-fr_100g                                              float64
# nutrition-score-uk_100g                                              float64
# glycemic-index_100g                                                  float64
# water-hardness_100g                                                  float64
# choline_100g                                                         float64
# phylloquinone_100g                                                   float64
# beta-glucan_100g                                                     float64
# inositol_100g                                                        float64
# carnitine_100g                                                       float64
# dtype: object

# %%
data_b.head()
# Out:
#    Unnamed: 0         code                                                url  \
# 0        8192  11110024800  http://world-en.openfoodfacts.org/product/0011...
# 1        8193  11110024893  http://world-en.openfoodfacts.org/product/0011...
# 2        8196  11110025029  http://world-en.openfoodfacts.org/product/0011...
# 3        8202  11110025203  http://world-en.openfoodfacts.org/product/0011...
# 4        8203  11110025241  http://world-en.openfoodfacts.org/product/0011...
#
#            creator           created_t          created_datetime  \
# 0  usda-ndb-import 2017-03-09 13:11:25 2017-03-09 13:11:25+00:00
# 1  usda-ndb-import 2017-03-09 21:09:38 2017-03-09 21:09:38+00:00
# 2  usda-ndb-import 2017-03-09 15:25:20 2017-03-09 15:25:20+00:00
# 3  usda-ndb-import 2017-03-09 14:05:44 2017-03-09 14:05:44+00:00
# 4  usda-ndb-import 2017-03-09 16:43:40 2017-03-09 16:43:40+00:00
#
#       last_modified_t    last_modified_datetime  \
# 0 2022-02-08 01:35:53 2022-02-08 01:35:53+00:00
# 1 2020-09-21 21:57:38 2020-09-21 21:57:38+00:00
# 2 2021-12-17 15:09:37 2021-12-17 15:09:37+00:00
# 3 2020-04-22 18:58:34 2020-04-22 18:58:34+00:00
# 4 2020-04-22 21:00:13 2020-04-22 21:00:13+00:00
#
#                                product_name abbreviated_product_name  \
# 0           Sea salt roasted deluxe nut mix                      NaN
# 1               Chunky blue cheese dressing                      NaN
# 2    100% Unfiltered Juice From Concentrate                      NaN
# 3  Kroger, english muffins, cinnamon raisin                      NaN
# 4   Bakery fresh goodness, multigrain bread                      NaN
#
#   generic_name quantity packaging packaging_tags packaging_en packaging_text  \
# 0          NaN    16 oz       NaN            NaN          NaN            NaN
# 1          NaN      NaN       NaN            NaN          NaN            NaN
# 2          NaN      NaN       NaN            NaN          NaN            NaN
# 3          NaN      NaN       NaN            NaN          NaN            NaN
# 4          NaN      NaN       NaN            NaN          NaN            NaN
#
#                                    brands  \
# 0                    Simple Truth Organic
# 1                              Fred Meyer
# 2                   Kroger,The Kroger Co.
# 3                                  Kroger
# 4  Bakery Fresh Goodness,  The Kroger Co.
#
#                            brands_tags  \
# 0                 simple-truth-organic
# 1                           fred-meyer
# 2                 kroger,the-kroger-co
# 3                               kroger
# 4  bakery-fresh-goodness,the-kroger-co
#
# 1                     Sauces
# 2  Concentrated apple juices
# 3                     Breads
# 4                     Breads
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1                                                NaN
# 2  https://images.openfoodfacts.org/images/produc...
# 3                                                NaN
# 4                                                NaN
#
#                                      image_small_url image_ingredients_url  \
# 0  https://images.openfoodfacts.org/images/produc...                   NaN
# 1                                                NaN                   NaN
# 2  https://images.openfoodfacts.org/images/produc...                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#   image_ingredients_small_url  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                  image_nutrition_url  \
# 0                                                NaN
# 1                                                NaN
# 2  https://images.openfoodfacts.org/images/produc...
# 3                                                NaN
# 4                                                NaN
#
#                            image_nutrition_small_url  energy-kj_100g  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  https://images.openfoodfacts.org/images/produc...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    energy-kcal_100g  energy_100g  energy-from-fat_100g  fat_100g  \
# 0        607.140000       2540.0                   NaN     57.14
# 1        517.000000       2163.0                   NaN     55.17
# 2         45.833333        192.0                   NaN      0.00
# 3        262.000000       1096.0                   NaN      0.82
# 4        280.000000       1172.0                   NaN      4.00
#
#    saturated-fat_100g  -butyric-acid_100g  -caproic-acid_100g  \
# 0                7.14                 NaN                 NaN
# 1               10.34                 NaN                 NaN
# 2                0.00                 NaN                 NaN
# 3                0.00                 NaN                 NaN
# 4                0.00                 NaN                 NaN
#
#    -caprylic-acid_100g  -capric-acid_100g  -lauric-acid_100g  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#    -myristic-acid_100g  -palmitic-acid_100g  -stearic-acid_100g  \
# 0                  NaN                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2                  NaN                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#    -arachidic-acid_100g  -behenic-acid_100g  -lignoceric-acid_100g  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3                   NaN                 NaN                    NaN
# 4                   NaN                 NaN                    NaN
#
#    -cerotic-acid_100g  -montanic-acid_100g  -melissic-acid_100g  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    monounsaturated-fat_100g  polyunsaturated-fat_100g  omega-3-fat_100g  \
# 0                     28.57                     10.71               NaN
# 1                       NaN                       NaN               NaN
# 2                       NaN                       NaN               NaN
# 3                      0.00                      0.82               NaN
# 4                       NaN                       NaN               NaN
#
#    -alpha-linolenic-acid_100g  -eicosapentaenoic-acid_100g  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    -docosahexaenoic-acid_100g  omega-6-fat_100g  -linoleic-acid_100g  \
# 0                         NaN               NaN                  NaN
# 1                         NaN               NaN                  NaN
# 2                         NaN               NaN                  NaN
# 3                         NaN               NaN                  NaN
# 4                         NaN               NaN                  NaN
#
#    -arachidonic-acid_100g  -gamma-linolenic-acid_100g  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    -dihomo-gamma-linolenic-acid_100g  omega-9-fat_100g  -oleic-acid_100g  \
# 0                                NaN               NaN               NaN
# 1                                NaN               NaN               NaN
# 2                                NaN               NaN               NaN
# 3                                NaN               NaN               NaN
# 4                                NaN               NaN               NaN
#
#    -elaidic-acid_100g  -gondoic-acid_100g  -mead-acid_100g  -erucic-acid_100g  \
# 0                 NaN                 NaN              NaN                NaN
# 1                 NaN                 NaN              NaN                NaN
# 2                 NaN                 NaN              NaN                NaN
# 3                 NaN                 NaN              NaN                NaN
# 4                 NaN                 NaN              NaN                NaN
#
#    -nervonic-acid_100g  trans-fat_100g  cholesterol_100g  carbohydrates_100g  \
# 0                  NaN             0.0             0.000           21.430000
# 1                  NaN             0.0             0.034            3.450000
# 2                  NaN             0.0             0.000           11.666667
# 3                  NaN             0.0             0.000           55.740000
# 4                  NaN             0.0             0.000           52.000000
#
#    sugars_100g  -sucrose_100g  -glucose_100g  -fructose_100g  -lactose_100g  \
# 0     3.570000            NaN            NaN             NaN            NaN
# 1     3.450000            NaN            NaN             NaN            NaN
# 2    11.666667            NaN            NaN             NaN            NaN
# 3    16.390000            NaN            NaN             NaN            NaN
# 4     8.000000            NaN            NaN             NaN            NaN
#
#    -maltose_100g  -maltodextrins_100g  starch_100g  polyols_100g  fiber_100g  \
# 0            NaN                  NaN          NaN           NaN        7.14
# 1            NaN                  NaN          NaN           NaN        0.00
# 2            NaN                  NaN          NaN           NaN        0.00
# 3            NaN                  NaN          NaN           NaN        3.30
# 4            NaN                  NaN          NaN           NaN        4.00
#
#    soluble-fiber_100g  insoluble-fiber_100g  proteins_100g  casein_100g  \
# 0                 NaN                   NaN          17.86          NaN
# 1                 NaN                   NaN           3.45          NaN
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN

# %% [markdown]
# ### Variables d'intérêt

# %% [markdown]
# #### Sélections des variables d'interet

# %%
var_int  = ['code',
            'product_name',
            'nova_group',
            'nutriscore_score',
            'nutriscore_grade',
            'energy_100g',
            'fat_100g', 
            'saturated-fat_100g', 
            'trans-fat_100g', 
            'carbohydrates_100g', 
            'sugars_100g',
            'fiber_100g',
            'proteins_100g', 
            'salt_100g',
            'sodium_100g',
            'alcohol_100g', 
            'fruits-vegetables-nuts_100g',
            'ingredients_text',
            'additives_n',
            'url']

# %%
data_int = data_b[var_int]

# %%
data_int.shape
# Out:
# (253678, 20)

# %% [markdown]
# #### Visualisation

# %%
def visu(dataf) : # Fonction visualisation du taux de remplissage
    df = pd.DataFrame(index=['Valeurs manquantes','Nombre de valeurs' ,'Taux de remplissage','Valeurs différentes'], columns= dataf.columns )
    
    for v in dataf.columns:
        #Somme des valeurs manquantes
        df.loc['Valeurs manquantes', v] = dataf[v].isnull().sum()
        # Nombre de valeurs 
        df.loc['Nombre de valeurs', v] = dataf.shape[0] - dataf[v].isnull().sum()
        #Taux de remplissage en %
        df.loc['Taux de remplissage', v] =((dataf.shape[0]- dataf[v].isnull().sum())/(dataf.shape[0]*1.0))*100 
        # Nombre de valeurs différentes
        df.loc['Valeurs différentes', v] = dataf[v].nunique()
        
    df1 = df.T #Tranposition du Dataframe
    # Conversion du type des colonnes
    df1['Valeurs manquantes'] = df1['Valeurs manquantes'].astype(int) 
    df1['Nombre de valeurs'] = df1['Nombre de valeurs'].astype(int)
    df1['Taux de remplissage'] = df1['Taux de remplissage'].astype(float)
    df1['Valeurs différentes'] = df1['Valeurs différentes'].astype(int)
    df1 = df1.sort_values(by=['Taux de remplissage'], ascending = False)
    
    plt.figure(figsize= (10,8))
    sns.set_theme()
    sns.barplot(df1["Taux de remplissage"], y=df1.index, palette="YlOrBr_r")
    plt.xlabel("Taux de remplissage en (%)", fontsize=13)
    plt.ylabel("Colonnes", fontsize=13)
    plt.title("Taux de replissage des colonnes", fontsize=16)
    plt.axvline(x=20, color='w')
    plt.axvline(x=80, color='w')
    plt.savefig("./Visualisations/Taux {}".format('dataf'), bbox_inches='tight')
    
    plt.show()
    
    return df

# %%
visu(data_int)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        0         4047      43100            76317
# Nombre de valeurs    253678       249631     210578           177361
# Taux de remplissage   100.0     98.40467  83.009958        69.915799
# Valeurs différentes  253568       194440          4               54
#
#                     nutriscore_grade energy_100g   fat_100g  \
# Valeurs manquantes             76317       20688      22576
# Nombre de valeurs             177361      232990     231102
# Taux de remplissage        69.915799    91.84478  91.100529
# Valeurs différentes                5        3518       4499
#
#                     saturated-fat_100g trans-fat_100g carbohydrates_100g  \
# Valeurs manquantes               40190         132295              22544
# Nombre de valeurs               213488         121383             231134
# Taux de remplissage          84.157081      47.849242          91.113143
# Valeurs différentes               2938            383               7221
#
#                     sugars_100g fiber_100g proteins_100g  salt_100g  \
# Valeurs manquantes        28734      75239         21325      23453
# Nombre de valeurs        224944     178439        232353     230225
# Taux de remplissage   88.673042  70.340747     91.593674  90.754815
# Valeurs différentes        5410       1482          3548       9282
#
#                     sodium_100g alcohol_100g fruits-vegetables-nuts_100g  \
# Valeurs manquantes        23455       249703                      249177
# Nombre de valeurs        230223         3975                        4501
# Taux de remplissage   90.754027     1.566947                    1.774297
# Valeurs différentes        9131          145                         738
#
#                     ingredients_text additives_n     url
# Valeurs manquantes             25621       25621       0
# Nombre de valeurs             228057      228057  253678
# Taux de remplissage        89.900188   89.900188   100.0
# Valeurs différentes           191676          33  253677

# %%
data_int.describe()
# Out:
#           nova_group  nutriscore_score    energy_100g       fat_100g  \
# count
100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 1275               0.0               38.89         8.33         1.9
# 1421               0.0                0.00          NaN         NaN
# 1658               0.0                0.00          NaN         NaN
# 1826               0.0                0.00         0.00         0.0
# 1954               NaN                0.00          NaN         NaN
# ...                ...                 ...          ...         ...
# 253648             NaN                 NaN          NaN         NaN
# 253650             NaN                 NaN          NaN         NaN
# 253653             NaN                 NaN          NaN         NaN
# 253663             NaN                 NaN          NaN         NaN
# 253673             NaN                 NaN          NaN         NaN
#
#         proteins_100g  salt_100g  sodium_100g  alcohol_100g  \
# 1275             5.56      0.625         0.25           NaN
# 1421             0.00      0.000         0.00           NaN
# 1658             0.00      0.000         0.00           NaN
# 1826             0.00      0.000         0.00           NaN
# 1954             0.00      0.000         0.00           NaN
# ...               ...        ...          ...           ...
# 253648            NaN        NaN          NaN           NaN
# 253650            NaN        NaN          NaN           NaN
# 253653            NaN        NaN          NaN           NaN
# 253663            NaN        NaN          NaN           NaN
# 253673            NaN        NaN          NaN           NaN
#
#         fruits-vegetables-nuts_100g  \
# 1275                            NaN
# 1421                            NaN
# 1658                            NaN
# 1826                            NaN
# 1954                            NaN
# ...                             ...
# 253648                          NaN
# 253650                          NaN
# 253653                          NaN
# 253663                          NaN
# 253673                          NaN
#
#                                          ingredients_text  additives_n  \
# 1275    Enriched bleached wheat flour (flour, niacin, ...          7.0
# 1421                              Extra virgin olive oil.          0.0
# 1658                      Organic extra virgin olive oil.          0.0
# 1826                              Extra virgin olive oil.          0.0
# 1954                              Extra virgin olive oil.          0.0
# ...                                                   ...          ...
# 253648                                                NaN          NaN
# 253650                                                NaN          NaN
# 253653                                                NaN          NaN
# 253663                                                NaN          NaN
# 253673                                                NaN          NaN
#
#                                                       url
# 1275    http://world-en.openfoodfacts.org/product/0011...
# 1421    http://world-en.openfoodfacts.org/product/0011...
# 1658    http://world-en.openfoodfacts.org/product/0011...
# 1826    http://world-en.openfoodfacts.org/product/0011...
# 1954    http://world-en.openfoodfacts.org/product/0011...
# ...                                                   ...
# 253648  http://world-en.openfoodfacts.org/product/9680...
# 253650  http://world-en.openfoodfacts.org/product/9688...
# 253653  http://world-en.openfoodfacts.org/product/9691...
# 253663  http://world-en.openfoodfacts.org/product/9870...
# 253673  http://world-en.openfoodfacts.org/product/9941...
#
# [4047 rows x 20 columns]

# %%
data_int.shape
# Out:
# (253678, 20)

# %%
data_int.dropna(subset=['code', 'product_name'], inplace=True)

# %%
data_int.shape
# Out:
# (249631, 20)

# %%
data_int.describe()
# Out:
#           nova_group  nutriscore_score    energy_100g       fat_100g  \
# count  210026.000000     176955.000000  232053.000000  230192.000000
# mean        3.393532          8.694340    1111.196973      12.569320
# std         0.989601          9.054399    1310.368648      17.388273
# min         1.000000        -15.000000       0.000000       0.000000
# 25%         3.000000          1.000000     363.000000       0.002500
# 50%         4.000000          9.000000    1071.000000       4.929800
# 75%         4.000000         15.000000    1670.000000      20.000000
# max         4.000000         38.000000  500000.000000     110.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g    sugars_100g  \
# count       212625.000000   121157.000000       230226.000000  224093.000000
# mean             4.877086        0.062588           31.397660      15.372211
# std              7.968954        1.523171           29.646234      20.876577
# min              0.000000        0.000000            0.000000      -0.100000
# 25%              0.000000        0.000000            5.420000       1.000000
# 50%              1.600000        0.000000           20.000000       5.000000
# 75%              7.000000        0.000000           57.450000      22.730000
# max            910.000000      369.000000         2916.670000     166.670000
#
#           fiber_100g  proteins_100g      salt_100g    sodium_100g  \
# count  177846.000000  231426.000000  229325.000000  229323.000000
# mean        2.796605       6.987875       1.704933       0.682226
# std         4.575501       8.087183      15.834535       6.335079
# min        -6.700000       0.000000       0.000000       0.000000
# 25%         0.000000       0.700000       0.052500       0.021000
# 50%         1.500000       4.620000       0.535000       0.214000
# 75%         3.600000      10.000000       1.322500       0.529000
# max       250.000000     175.000000    3250.000000    1300.000000
#
#        alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count   3933.000000                  4482.000000  227284.000000
# mean       5.833054                    35.880017       2.154828
# std        9.625702                    37.713953       3.005940
# min        0.000000                     0.000000       0.000000
# 25%        0.000000                     0.000000       0.000000
# 50%        0.000000                    22.000000       1.000000
# 75%        8.000000                    65.000000       3.000000
# max      100.000000                   100.000000      32.000000

# %% [markdown]
# #### Supprimer les lignes sans données pour les lipides, les glucides et les protéines

# %%
df_miss = data_int.loc[(data_int["fat_100g"].isnull() & 
                        data_int["carbohydrates_100g"].isnull() & 
                        data_int["proteins_100g"].isnull())]

df_miss
# Out:
#                  code                          product_name  nova_group  \
# 717       11110633606     Sweet Bourbon Flavoured Bratwurst         4.0
# 877       11110712387                     Chicken seasoning         4.0
# 1316      11110816405               Purified drinking water         1.0
# 1864      11110852991                Restaurant Style Salsa         NaN
# 1886      11110853905  Extra Virgin Olive Oil Cooking Spray         4.0
# ...               ...                                   ...         ...
# 253669  9906410000009             Roussette du Bugey (2011)         NaN
# 253671           9918            Cheese cake thé vert, yuzu         NaN
# 253672  9935010000003                        Rillette d'oie         3.0
# 253674  9948282780603                     Tomato & ricotta          NaN
# 253676  9970229501521                               乐吧泡菜味薯片         NaN
#
#         nutriscore_score nutriscore_grade  energy_100g  fat_100g  \
# 717                  NaN              NaN          NaN       NaN
# 877                  NaN              NaN          NaN       NaN
# 1316                 0.0                a          NaN       NaN
# 1864                 NaN              NaN          NaN       NaN
# 1886                 NaN              NaN          NaN       NaN
# ...                  ...              ...          ...       ...
# 253669               NaN              NaN          NaN       NaN
# 253671               NaN              NaN          NaN       NaN
# 253672               NaN              NaN          NaN       NaN
# 253674               NaN              NaN          NaN       NaN
# 253676               NaN              NaN          NaN       NaN
#
#         saturated-fat_100g  trans-fat_100g  carbohydrates_100g  sugars_100g  \
# 717                    NaN             NaN                 NaN          NaN
# 877                    NaN             NaN                 NaN          NaN
# 1316                   NaN             NaN                 NaN          NaN
# 1864                   NaN             NaN                 NaN          NaN
# 1886                   NaN             NaN                 NaN          NaN
# ...                    ...             ...                 ...          ...
# 253669                 NaN             NaN                 NaN          NaN
# 253671                 NaN             NaN                 NaN          NaN
# 253672                 NaN             NaN                 NaN          NaN
# 253674                 NaN             NaN                 NaN          NaN
# 253676                 NaN             NaN                 NaN          NaN
#
#         fiber_100g  proteins_100g  salt_100g  sodium_100g  alcohol_100g  \
# 717            NaN            NaN        NaN          NaN           NaN
# 877            NaN            NaN      45.72       18.288           NaN
# 1316           NaN            NaN        NaN          NaN           NaN
# 1864           NaN            NaN        NaN          NaN           NaN
# 1886           NaN            NaN        NaN          NaN           NaN
# ...            ...            ...        ...          ...           ...
# 253669         NaN            NaN        NaN          NaN          12.0
# 253671         NaN            NaN        NaN          NaN           NaN
# 253672         NaN            NaN        NaN          NaN           NaN
# 253674         NaN            NaN        NaN          NaN           NaN
# 253676         NaN            NaN        NaN          NaN           NaN
#
#         fruits-vegetables-nuts_100g  \
# 717                             NaN
# 877                             NaN
# 1316                            NaN
# 1864                            NaN
# 1886                            NaN
# ...                             ...
# 253669                          NaN
# 253671                          NaN
# 253672                          NaN
# 253674                          NaN
# 253676                          NaN
#
#                                          ingredients_text  additives_n  \
# 717     PORK, WATER, CORN SYRUP CONTAINS 2% OR LESS 0F...          2.0
# 877     Salt, spices, paprika, onion*, maltodextrin, d...          0.0
# 1316                                       purified water          0.0
# 1864                                                  NaN          NaN
# 1886    Organic extra virgin olive oil*, organic grain...          1.0
# ...                                                   ...          ...
# 253669                                                NaN          NaN
# 253671                                                NaN          NaN
# 253672  viande d'oie, graisse de canard, épices, sel, ...          0.0
# 253674                                                NaN          NaN
# 253676                                                NaN          NaN
#
#                                                       url
# 717     http://world-en.openfoodfacts.org/product/0011...
# 877     http://world-en.openfoodfacts.org/product/0011...
# 1316    http://world-en.openfoodfacts.org/product/0011...
# 1864    http://world-en.openfoodfacts.org/product/0011...
# 1886    http://world-en.openfoodfacts.org/product/0011...
# ...                                                   ...
# 253669  http://world-en.openfoodfacts.org/product/9906...
# 253671  http://world-en.openfoodfacts.org/product/9918...
# 253672  http://world-en.openfoodfacts.org/product/9935...
# 253674  http://world-en.openfoodfacts.org/product/9948...
# 253676  http://world-en.openfoodfacts.org/product/9970...
#
# [17477 rows x 20 columns]

# %%
data_int.drop(df_miss.index, axis=0, inplace=True)

# %% [markdown]
# #### Traitement des outliers min

# %%
data_int.loc[(data_int['trans-fat_100g'] <0 )|
             (data_int['sugars_100g'] <0 )|
             (data_int['proteins_100g'] <0 )|
             (data_int[ 'fiber_100g' ] <0) ]
# Out:
#                  code                               product_name  nova_group  \
# 16510     28400231053  Traditional Tender Cracklins Chicharrones         NaN
# 158086  3161712000928                          Caprice des dieux         3.0
#
#         nutriscore_score nutriscore_grade  energy_100g  fat_100g  \
# 16510                NaN              NaN       2230.0     33.33
# 158086              15.0                d       1379.0     30.00
#
#         saturated-fat_100g  trans-fat_100g  carbohydrates_100g  sugars_100g  \
# 16510                13.33             0.0                 0.0          0.0
# 158086               21.00             NaN                 0.8         -0.1
#
#         fiber_100g  proteins_100g  salt_100g  sodium_100g  alcohol_100g  \
# 16510         -6.7            NaN    6.43382     2.573528           NaN
# 158086         NaN           15.3    1.40000     0.560000           NaN
#
#         fruits-vegetables-nuts_100g  \
# 16510                           NaN
# 158086                          NaN
#
#                                          ingredients_text  additives_n  \
# 16510                      Fried pork cracklins and salt.          0.0
# 158086  _Lait_ de vache, _crème_, sel, ferments lactiq...          0.0
#
#                                                       url
# 16510   http://world-en.openfoodfacts.org/product/0028...
# 158086  http://world-en.openfoodfacts.org/product/3161...

# %%
data_int.describe()
# Out:
#          nova_group  nutriscore_score    energy_100g       fat_100g  \
# count  203116.00000     176551.000000  231755.000000  230192.000000
# mean        3.41978          8.713193    1112.083582      12.569320
# std         0.96953          9.055614    1310.788958      17.388273
# min         1.00000        -15.000000       0.000000       0.000000
# 25%         3.00000          1.000000     364.000000       0.002500
# 50%         4.00000          9.000000    1071.000000       4.929800
# 75%         4.00000         15.000000    1671.000000      20.000000
# max         4.00000         38.000000  500000.000000     110.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g    sugars_100g  \
# count        212527.00000   121154.000000       230226.000000  223992.000000
# mean              4.87932        0.062589           31.397660      15.374660
# std               7.97011        1.523190           29.646234      20.875147
# min               0.00000        0.000000            0.000000      -0.100000
# 25%               0.00000        0.000000            5.420000       1.010000
# 50%               1.61000        0.000000           20.000000       5.000000
# 75%               7.00000        0.000000           57.450000      22.730000
# max             910.00000      369.000000         2916.670000     166.670000
#
#           fiber_100g  proteins_100g      salt_100g    sodium_100g  \
# count  177841.000000  231426.000000  228987.000000  228985.000000
# mean        2.796253       6.987875       1.703387       0.681609
# std         4.572655       8.087183      15.835824       6.335598
# min        -6.700000       0.000000       0.000000       0.000000
# 25%         0.000000       0.700000       0.055000       0.022000
# 50%         1.500000       4.620000       0.535000       0.214000
# 75%         3.600000      10.000000       1.327500       0.531000
# max       250.000000     175.000000    3250.000000    1300.000000
#
#        alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count   2252.000000                  4453.000000  218984.000000
# mean       1.129089                    35.805330       2.207184
# std        5.256990                    37.755147       3.028264
# min        0.000000                     0.000000       0.000000
# 25%        0.000000                     0.000000       0.000000
# 50%        0.000000                    22.000000       1.000000
# 75%        0.000000                    65.000000       3.000000
# max      100.000000                   100.000000      32.000000

# %%
out_min= ['energy_100g','fat_100g','sugars_100g','proteins_100g', 'fiber_100g' ]

data_int[out_min] = abs(data_int[out_min])

# %% [markdown]
# #### Traitement outliers max

# %%
df_max = data_int.loc[(data_int['fat_100g'] > 100) |
            (data_int['saturated-fat_100g'] > 100) |
            (data_int['trans-fat_100g'] > 100) |
            (data_int['carbohydrates_100g'] > 100) |
            (data_int['sugars_100g'] > 100) |
            (data_int['proteins_100g'] > 100) |
            (data_int['salt_100g'] > 100) |
            (data_int['fiber_100g'] > 100) | 
            (data_int['sodium_100g'] > 100)]

# %%
df_max.shape
# Out:
# (110, 20)

# %%
data_int.shape
# Out:
# (232154, 20)

# %%
data_int.drop(df_max.index, axis = 0, inplace = True)

# %%
data_int.shape
# Out:
# (232044, 20)

# %%
data_int.describe()
# Out:
#           nova_group  nutriscore_score    energy_100g       fat_100g  \
# count  203059.000000     176527.000000  231649.000000  230084.000000
# mean        3.419839          8.712679    1110.102110      12.572625
# std         0.969519          9.055698     802.331588      17.388825
# min         1.000000        -15.000000       0.000000       0.000000
# 25%         3.000000          1.000000     364.000000       0.010000
# 50%         4.000000          9.000000    1071.000000       4.930000
# 75%         4.000000         15.000000    1671.000000      20.000000
# max         4.000000         38.000000   15481.000000     100.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g    sugars_100g  \
# count       212457.000000   121109.000000       230119.000000  223925.000000
# mean             4.874331        0.055024           31.385894      15.372692
# std              7.711707        0.742318           29.017914      20.868733
# min              0.000000        0.000000            0.000000       0.000000
# 25%              0.000000        0.000000            5.420000       1.010000
# 50%              1.610000        0.000000           20.000000       5.000000
# 75%              7.000000        0.000000           57.450000      22.730000
# max            100.000000       83.000000          100.000000     100.000000
#
#           fiber_100g  proteins_100g      salt_100g    sodium_100g  \
# count  177781.000000  231325.000000  228882.000000  228880.000000
# mean        2.794889       6.988556       1.536542       0.614867
# std         4.534502       8.079205       6.171557       2.471016
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.700000       0.055000       0.022000
# 50%         1.500000       4.620000       0.535000       0.214000
# 75%         3.600000      10.000000       1.322500       0.529000
# max       100.000000     100.000000     100.000000      49.987200
#
#        alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count   2250.000000                  4453.000000  218881.000000
# mean       1.130093                    35.805330       2.207894
# std        5.259219                    37.755147       3.028599
# min        0.000000                     0.000000       0.000000
# 25%        0.000000                     0.000000       0.000000
# 50%        0.000000                    22.000000       1.000000
# 75%        0.000000                    65.000000       3.000000
# max      100.000000                   100.000000      32.000000

# %% [markdown]
# #### Cas particulier
#
# - les graisses saturées et les acide gras ne peuvent pas être supérieur aux graisses
# - les sucres ne peuvent pas être supérieur aux glucides

# %%
df_part = data_int.loc[(data_int['fat_100g'] < (data_int['saturated-fat_100g'] + data_int['trans-fat_100g'])) |
                       (data_int['carbohydrates_100g'] < data_int['sugars_100g'])]

# %%
df_part.shape
# Out:
# (700, 20)

# %%
data_int.drop(df_part.index, axis = 0, inplace = True)

# %%
data_int.shape
# Out:
# (231344, 20)

# %%
data_int.describe()
# Out:
#           nova_group  nutriscore_score   energy_100g       fat_100g  \
# count  202552.000000     176220.000000  230951.00000  229385.000000
# mean        3.419566          8.713143    1110.45489      12.578981
# std         0.969744          9.055975     801.91544      17.394254
# min         1.000000        -15.000000       0.00000       0.000000
# 25%         3.000000          1.000000     364.00000       0.020000
# 50%         4.000000          9.000000    1071.00000       5.000000
# 75%         4.000000         15.000000    1674.00000      20.000000
# max         4.000000         38.000000   15481.00000     100.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g    sugars_100g  \
# count       211796.000000   120589.000000       229419.000000  223230.000000
# mean             4.869099        0.048055           31.421453      15.351275
# std              7.700217        0.573177           29.020864      20.847754
# min              0.000000        0.000000            0.000000       0.000000
# 25%              0.000000        0.000000            5.420000       1.000000
# 50%              1.610000        0.000000           20.000000       5.000000
# 75%              7.000000        0.000000           57.500000      22.730000
# max            100.000000       35.710000          100.000000     100.000000
#
#           fiber_100g  proteins_100g      salt_100g    sodium_100g  \
# count  177185.000000  230628.000000  228189.000000  228187.000000
# mean        2.796206       6.986961       1.534703       0.614133
# std         4.529075       8.073091       6.164834       2.468337
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.700000       0.055000       0.022000
# 50%         1.500000       4.650000       0.535000       0.214000
# 75%         3.600000      10.000000       1.322500       0.529000
# max       100.000000     100.000000     100.000000      49.987200
#
#        alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count   2247.000000                  4451.000000  218193.000000
# mean       1.131602                    35.796727       2.210190
# std        5.262568                    37.755524       3.030406
# min        0.000000                     0.000000       0.000000
# 25%        0.000000                     0.000000       0.000000
# 50%        0.000000                    22.000000       1.000000
# 75%        0.000000                    65.000000       3.000000
# max      100.000000                   100.000000      32.000000

# %% [markdown]
# #### Visualisation

# %%
visu(data_int)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        0            0      28792            55124
# Nombre de valeurs    231344       231344     202552           176220
# Taux de remplissage   100.0        100.0  87.554464         76.17228
# Valeurs différentes  231247       179813          4               54
#
#                     nutriscore_grade energy_100g   fat_100g  \
# Valeurs manquantes             55124         393       1959
# Nombre de valeurs             176220      230951     229385
# Taux de remplissage         76.17228   99.830123  99.153209
# Valeurs différentes                5        3505       4492
#
#                     saturated-fat_100g trans-fat_100g carbohydrates_100g  \
# Valeurs manquantes               19548         110755               1925
# Nombre de valeurs               211796         120589             229419
# Taux de remplissage          91.550246      52.125406          99.167906
# Valeurs différentes               2922            358               7193
#
#                     sugars_100g fiber_100g proteins_100g salt_100g  \
# Valeurs manquantes         8114      54159           716      3155
# Nombre de valeurs        223230     177185        230628    228189
# Taux de remplissage   96.492669  76.589408     99.690504  98.63623
# Valeurs différentes        5383       1473          3539      9115
#
#                     sodium_100g alcohol_100g fruits-vegetables-nuts_100g  \
# Valeurs manquantes         3157       229097                      226893
# Nombre de valeurs        228187         2247                        4451
# Taux de remplissage   98.635366     0.971281                    1.923975
# Valeurs différentes        8970           83                         734
#
#                     ingredients_text additives_n     url
# Valeurs manquantes             13151       13151       0
# Nombre de valeurs             218193      218193  231344
# Taux de remplissage        94.315392   94.315392   100.0
# Valeurs différentes           183719          33  231343

# %% [markdown]
# ### Imputation

# %% [markdown]
# #### Imputation par 0

# %%
imp = ['fiber_100g',
       'alcohol_100g',
       'fruits-vegetables-nuts_100g',
       'additives_n']

# %%
for i in imp:
    data_int[i].fillna(0, inplace=True) #remplace les valeurs manquantes par 0
    
data_int['ingredients_text'].fillna('0',inplace= True)

# %%
visu(data_int)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Calcul des énergies manquantes
#
#     Calcul pour 100g:
#         Energy(kcal) = 9*fats + 4*Carbohydrates + 4*protein
#         Energy(kJ) = 4,1868*Energy(kcal)
#         L'energie ne peut pas dépasser les 3768 kJ

# %%
for l, r in data_int.loc[data_int['energy_100g'].isnull() | (data_int['energy_100g']> 3769)].iterrows():
    r['energy_100g'] = ((9*r['fat_100g'] + 4*r['carbohydrates_100g'] + 4*r['proteins_100g']) * 4.1868)
    data_int.loc[l,'energy_100g'] = r['energy_100g']

# %%
df_energ = data_int.loc[(data_int['energy_100g']> 3769)]
data_int.drop(df_energ.index, axis = 0, inplace = True)

# %%
data_int.describe()
# Out:
#           nova_group  nutriscore_score    energy_100g       fat_100g  \
# count  202550.000000     176218.000000  231099.000000  229373.000000
# mean        3.419570          8.713066    1108.808646      12.575227
# std         0.969743          9.055985     796.644980      17.386696
# min         1.000000        -15.000000       0.000000       0.000000
# 25%         3.000000          1.000000     364.000000       0.020000
# 50%         4.000000          9.000000    1071.000000       5.000000
# 75%         4.000000         15.000000    1670.000000      20.000000
# max         4.000000         38.000000    3768.120000     100.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g    sugars_100g  \
# count       211786.000000   120579.000000       229407.000000  223218.000000
# mean             4.868321        0.047995           31.420421      15.350906
# std              7.697844        0.572983           29.020468      20.847173
# min              0.000000        0.000000            0.000000       0.000000
# 25%              0.000000        0.000000            5.420000       1.000000
# 50%              1.610000        0.000000           20.000000       5.000000
# 75%              7.000000        0.000000           57.500000      22.730000
# max            100.000000       35.710000          100.000000     100.000000
#
#           fiber_100g  proteins_100g     salt_100g    sodium_100g  \
# count  231332.000000  230616.000000  228177.00000  228175.000000
# mean        2.141346       6.986155       1.53470       0.614131
# std         4.136399       8.072279       6.16498       2.468395
# min         0.000000       0.000000       0.00000       0.000000
# 25%         0.000000       0.700000       0.05500       0.022000
# 50%         0.300000       4.650000       0.53500       0.214000
# 75%         2.900000      10.000000       1.32250       0.529000
# max       100.000000     100.000000     100.00000      49.987200
#
#         alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count  231332.000000                231332.000000  231332.000000
# mean        0.010992                     0.688756       2.084653
# std         0.530288                     7.183465       2.987219
# min         0.000000                     0.000000       0.000000
# 25%         0.000000                     0.000000       0.000000
# 50%         0.000000                     0.000000       1.000000
# 75%         0.000000                     0.000000       3.000000
# max       100.000000                   100.000000      32.000000

# %%
visu(data_int)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        0            0      28782            55114
# Nombre de valeurs    231332       231332     202550           176218
# Taux de remplissage   100.0        100.0  87.558142        76.175367
# Valeurs différentes  231235       179805          4               54
#
#                     nutriscore_grade energy_100g   fat_100g  \
# Valeurs manquantes             55114         233       1959
# Nombre de valeurs             176218      231099     229373
# Taux de remplissage        76.175367   99.899279  99.153165
# Valeurs différentes                5        3602       4491
#
#                     saturated-fat_100g trans-fat_100g carbohydrates_100g  \
# Valeurs manquantes               19546         110753               1925
# Nombre de valeurs               211786         120579             229407
# Taux de remplissage          91.550672      52.123787          99.167863
# Valeurs différentes               2922            358               7193
#
#                     sugars_100g fiber_100g proteins_100g  salt_100g  \
# Valeurs manquantes         8114          0           716       3155
# Nombre de valeurs        223218     231332        230616     228177
# Taux de remplissage   96.492487      100.0     99.690488  98.636159
# Valeurs différentes        5383       1473          3539       9115
#
#                     sodium_100g alcohol_100g fruits-vegetables-nuts_100g  \
# Valeurs manquantes         3157            0                           0
# Nombre de valeurs        228175       231332                      231332
# Taux de remplissage   98.635295        100.0                       100.0
# Valeurs différentes        8970           83                         734
#
#                     ingredients_text additives_n     url
# Valeurs manquantes                 0           0       0
# Nombre de valeurs             231332      231332  231332
# Taux de remplissage            100.0       100.0   100.0
# Valeurs différentes           183709          33  231331

# %% [markdown]
# #### Supprimer les

# %%
df_100g = data_int.loc[(data_int['fat_100g'] + data_int['carbohydrates_100g'] + data_int['proteins_100g']) > 100]
df_100g.shape
# Out:
# (1410, 20)

# %%
data_int.drop(df_100g.index, axis = 0, inplace = True)

# %% [markdown]
# ### KNNImputer

# %%
data_int.reset_index(drop=True, inplace=True)

# %%
cor = data_int[['energy_100g',
                'fat_100g',
                'saturated-fat_100g',
                'trans-fat_100g',
                'carbohydrates_100g',
                'sugars_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
               'sodium_100g']]

# %%
plt.figure(figsize= (7,5))
sns.heatmap(cor.corr().round(2), annot=True)
# Out:
# <AxesSubplot:>

# %%
imputer0 = KNNImputer(n_neighbors=5) #Fixé a 5 voisins
imputer0.fit(data_int[['energy_100g','fat_100g',
                'saturated-fat_100g',
                'trans-fat_100g',
                'carbohydrates_100g',
                'sugars_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
               'sodium_100g']])
train = imputer0.transform(data_int[['energy_100g','fat_100g',
                'saturated-fat_100g',
                'trans-fat_100g',
                'carbohydrates_100g',
                'sugars_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
               'sodium_100g']])
print(sum(isnan(train).flatten()))
# Out:
# 0

# %%
df_train = pd.DataFrame(train, columns = ['energy_100g','fat_100g',
                'saturated-fat_100g',
                'trans-fat_100g',
                'carbohydrates_100g',
                'sugars_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
               'sodium_100g'])

# %%
visu(df_train)
# Out:
#                     energy_100g fat_100g saturated-fat_100g trans-fat_100g  \
# Valeurs manquantes            0        0                  0              0
# Nombre de valeurs        229922   229922             229922         229922
# Taux de remplissage       100.0    100.0              100.0          100.0
# Valeurs différentes        3714     5120               4128           1019
#
#                     carbohydrates_100g sugars_100g fiber_100g proteins_100g  \
# Valeurs manquantes                   0           0          0             0
# Nombre de valeurs               229922      229922     229922        229922
# Taux de remplissage              100.0       100.0      100.0         100.0
# Valeurs différentes               7980        6657       1469          3767
#
#                     salt_100g sodium_100g
# Valeurs manquantes          0           0
# Nombre de valeurs      229922      229922
# Taux de remplissage     100.0       100.0
# Valeurs différentes     10799       10692

# %%
df_first = data_int[["code", "product_name", 'nova_group',
            'nutriscore_score',
            'nutriscore_grade']]
df_last =  data_int[["alcohol_100g","fruits-vegetables-nuts_100g","ingredients_text","additives_n","url"]]

# %%
df_knn= pd.concat([df_first, df_train, df_last], axis=1)

# %%
visu(df_knn)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        0            0      28503            54495
# Nombre de valeurs    229922       229922     201419           175427
# Taux de remplissage   100.0        100.0  87.603187        76.298484
# Valeurs différentes  229825       178692          4               54
#
#                     nutriscore_grade energy_100g fat_100g saturated-fat_100g  \
# Valeurs manquantes             54495           0        0                  0
# Nombre de valeurs             175427      229922   229922             229922
# Taux de remplissage        76.298484       100.0    100.0              100.0
# Valeurs différentes                5        3714     5120               4128
#
#                     trans-fat_100g carbohydrates_100g sugars_100g fiber_100g  \
# Valeurs manquantes               0                  0           0          0
# Nombre de valeurs           229922             229922      229922     229922
# Taux de remplissage          100.0              100.0       100.0      100.0
# Valeurs différentes           1019               7980        6657       1469
#
#                     proteins_100g salt_100g sodium_100g alcohol_100g  \
# Valeurs manquantes              0         0           0            0
# Nombre de valeurs          229922    229922      229922       229922
# Taux de remplissage         100.0     100.0       100.0        100.0
# Valeurs différentes          3767     10799       10692           83
#
#                     fruits-vegetables-nuts_100g ingredients_text additives_n  \
# Valeurs manquantes                            0                0           0
# Nombre de valeurs                        229922           229922      229922
# Taux de remplissage                       100.0            100.0       100.0
# Valeurs différentes                         734           182537          33
#
#                         url
# Valeurs manquantes        0
# Nombre de valeurs    229922
# Taux de remplissage   100.0
# Valeurs différentes  229921

# %%
df_knn.describe()
# Out:
#           nova_group  nutriscore_score    energy_100g       fat_100g  \
# count  201419.000000     175427.000000  229922.000000  229922.000000
# mean        3.418183          8.680425    1102.149138      12.525247
# std         0.970829          9.046949     793.162657      17.286488
# min         1.000000        -15.000000       0.000000       0.000000
# 25%         3.000000          1.000000     360.000000       0.050000
# 50%         4.000000          9.000000    1061.000000       4.970143
# 75%         4.000000         15.000000    1653.000000      20.000000
# max         4.000000         38.000000    3768.120000     100.000000
#
#        saturated-fat_100g  trans-fat_100g  carbohydrates_100g   sugars_100g  \
# count       229922.000000   229922.000000       229922.000000  229922.00000
# mean             4.471684        0.044372           31.209514      14.88449
# std              7.451370        0.438618           28.849377      20.60350
# min              0.000000        0.000000            0.000000       0.00000
# 25%              0.000000        0.000000            5.420000       0.90000
# 50%              1.100000        0.000000           20.000000       4.80000
# 75%              6.250000        0.000000           57.140000      21.43000
# max            100.000000       35.710000          100.000000     100.00000
#
#           fiber_100g  proteins_100g      salt_100g    sodium_100g  \
# count  229922.000000  229922.000000  229922.000000  229922.000000
# mean        2.123446       6.958108       1.540635       0.612320
# std         4.115986       8.030788       6.159931       2.460538
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.700000       0.052500       0.021000
# 50%         0.300000       4.620000       0.535000       0.214000
# 75%         2.900000      10.000000       1.320800       0.528320
# max       100.000000     100.000000     100.000000      49.987200
#
#         alcohol_100g  fruits-vegetables-nuts_100g    additives_n
# count  229922.000000                229922.000000  229922.000000
# mean        0.011059                     0.692540       2.087947
# std         0.531911                     7.202278       2.990966
# min         0.000000                     0.000000       0.000000
# 25%         0.000000                     0.000000       0.000000
# 50%         0.000000                     0.000000       1.000000
# 75%         0.000000                     0.000000       3.000000
# max       100.000000                   100.000000      32.000000

# %%
df_out = df_knn.loc[((df_knn['fat_100g'] + df_knn['carbohydrates_100g'] + df_knn['proteins_100g']) > 100) | df_knn["product_name"].isnull()]
df_out.shape
# Out:
# (144, 20)

# %%
df_knn.drop(df_out.index, axis = 0, inplace = True)

# %%
df_knn.shape
# Out:
# (229778, 20)

# %%
df_knn.reset_index(drop=True, inplace=True)

# %%
plt.figure(figsize=(11,10))
sns.heatmap(df_knn.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
cor0 = df_knn[['nutriscore_score','energy_100g','fat_100g','saturated-fat_100g','carbohydrates_100g','sugars_100g']]

# %%
sns.heatmap(cor0.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
imputed_dataset = imputer0.fit_transform(cor0)
df_imp = pd.DataFrame(imputed_dataset, columns = cor0.columns)
df_imp.describe()
# Out:
#        nutriscore_score    energy_100g       fat_100g  saturated-fat_100g  \
# count     229778.000000  229778.000000  229778.000000       229778.000000
# mean           8.740179    1101.692176      12.509243            4.467391
# std            8.670772     792.916449      17.266904            7.438411
# min          -15.000000       0.000000       0.000000            0.000000
# 25%            1.000000     360.000000       0.030000            0.000000
# 50%            9.000000    1059.000000       4.929600            1.100000
# 75%           15.000000    1653.000000      20.000000            6.250000
# max           38.000000    3768.120000     100.000000          100.000000
#
#        carbohydrates_100g    sugars_100g
# count       229778.000000  229778.000000
# mean            31.191181      14.874612
# std             28.841313      20.592091
# min              0.000000       0.000000
# 25%              5.420000       0.900000
# 50%             20.000000       4.800000
# 75%             57.140000      21.430000
# max            100.000000     100.000000

# %%
df_imp.isnull().sum()
# Out:
# nutriscore_score      0
# energy_100g           0
# fat_100g              0
# saturated-fat_100g    0
# carbohydrates_100g    0
# sugars_100g           0
# dtype: int64

# %%
df_imp.shape
# Out:
# (229778, 6)

# %%
df_kf = df_knn[['code','product_name','nova_group',
            'nutriscore_grade']]
df_kl = df_knn[['trans-fat_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
                'sodium_100g',
                "alcohol_100g",
                "fruits-vegetables-nuts_100g",
                "ingredients_text",
                "additives_n",
                "url"]]
df_it = pd.concat([df_kf, df_imp, df_kl], axis=1)
df_it.shape
# Out:
# (229778, 20)

# %%
visu(df_it)
# Out:
#                        code product_name nova_group nutriscore_grade  \
# Valeurs manquantes        0            0      28450            54360
# Nombre de valeurs    229778       229778     201328           175418
# Taux de remplissage   100.0        100.0  87.618484        76.342383
# Valeurs différentes  229681       178591          4                5
#
#                     nutriscore_score energy_100g fat_100g saturated-fat_100g  \
# Valeurs manquantes                 0           0        0                  0
# Nombre de valeurs             229778      229778   229778             229778
# Taux de remplissage            100.0       100.0    100.0              100.0
# Valeurs différentes              217        3705     5093               4117
#
#                     carbohydrates_100g sugars_100g trans-fat_100g fiber_100g  \
# Valeurs manquantes                   0           0              0          0
# Nombre de valeurs               229778      229778         229778     229778
# Taux de remplissage              100.0       100.0          100.0      100.0
# Valeurs différentes               7956        6643           1018       1469
#
#                     proteins_100g salt_100g sodium_100g alcohol_100g  \
# Valeurs manquantes              0         0           0            0
# Nombre de valeurs          229778    229778      229778       229778
# Taux de remplissage         100.0     100.0       100.0        100.0
# Valeurs différentes          3733     10784       10677           83
#
#                     fruits-vegetables-nuts_100g ingredients_text additives_n  \
# Valeurs manquantes                            0                0           0
# Nombre de valeurs                        229778           229778      229778
# Taux de remplissage                       100.0            100.0       100.0
# Valeurs différentes                         734           182449          33
#
#                         url
# Valeurs manquantes        0
# Nombre de valeurs    229778
# Taux de remplissage   100.0
# Valeurs différentes  229777

# %% [markdown]
# ## Iterative Imputer

# %%
cor1 = df_it[['nova_group','nutriscore_score','additives_n']]

# %%
sns.heatmap(cor1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
imputer1 = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=None)
imputed_dataset = imputer1.fit_transform(cor1)
df_ite = pd.DataFrame(imputed_dataset, columns = cor1.columns)
df_ite.describe()
# Out:
#           nova_group  nutriscore_score    additives_n
# count  229778.000000     229778.000000  229778.000000
# mean        3.375843          8.740179       2.088603
# std         0.921576          8.670772       2.991486
# min         1.000000        -15.000000       0.000000
# 25%         3.000000          1.000000       0.000000
# 50%         4.000000          9.000000       1.000000
# 75%         4.000000         15.000000       3.000000
# max         4.261005         38.000000      32.000000

# %%
df_if = df_it[['code','product_name']]
df_il = df_it[['nutriscore_grade','energy_100g',
               'fat_100g',
                'saturated-fat_100g',
                'trans-fat_100g',
                'carbohydrates_100g',
                'sugars_100g',
                'fiber_100g',
                'proteins_100g',
                'salt_100g',
                'sodium_100g',
                "alcohol_100g",
                "fruits-vegetables-nuts_100g",
                "ingredients_text",
                "url"]]
df_final = pd.concat([df_if, df_ite, df_il], axis=1)
df_final.shape
# Out:
# (229778, 20)

# %% [markdown]
# ### Nutriscore grade

# %%
for l, r in df_final.loc[df_final["nutriscore_grade"].isnull()].iterrows():
    if r['nutriscore_score'] < 0:
        df_final.loc[l,"nutriscore_grade"] = 'a'
    elif -1 < r['nutriscore_score'] < 3:
        df_final.loc[l,"nutriscore_grade"] = 'b'
    elif 2 < r['nutriscore_score'] < 11:
        df_final.loc[l,"nutriscore_grade"] = 'c'
    elif 10 < r['nutriscore_score'] < 19:
        df_final.loc[l,"nutriscore_grade"] = 'd'
    else:
        df_final.loc[l,"nutriscore_grade"] = 'e'

# %%
visu(df_final)
# Out:
#                        code product_name nova_group nutriscore_score  \
# Valeurs manquantes        0            0          0                0
# Nombre de valeurs    229778       229778     229778           229778
# Taux de remplissage   100.0        100.0      100.0            100.0
# Valeurs différentes  229681       178591        566              217
#
#                     additives_n nutriscore_grade energy_100g fat_100g  \
# Valeurs manquantes            0                0           0        0
# Nombre de valeurs        229778           229778      229778   229778
# Taux de remplissage       100.0            100.0       100.0    100.0
# Valeurs différentes          33                5        3705     5093
#
#                     saturated-fat_100g trans-fat_100g carbohydrates_100g  \
# Valeurs manquantes                   0              0                  0
# Nombre de valeurs               229778         229778             229778
# Taux de remplissage              100.0          100.0              100.0
# Valeurs différentes               4117           1018               7956
#
#                     sugars_100g fiber_100g proteins_100g salt_100g  \
# Valeurs manquantes            0          0             0         0
# Nombre de valeurs        229778     229778        229778    229778
# Taux de remplissage       100.0      100.0         100.0     100.0
# Valeurs différentes        6643       1469          3733     10784
#
#                     sodium_100g alcohol_100g fruits-vegetables-nuts_100g  \
# Valeurs manquantes            0            0                           0
# Nombre de valeurs        229778       229778                      229778
# Taux de remplissage       100.0        100.0                       100.0
# Valeurs différentes       10677           83                         734
#
#                     ingredients_text     url
# Valeurs manquantes                 0       0
# Nombre de valeurs             229778  229778
# Taux de remplissage            100.0   100.0
# Valeurs différentes           182449  229777

# %%
df_final.describe()
# Out:
#           nova_group  nutriscore_score    additives_n    energy_100g  \
# count  229778.000000     229778.000000  229778.000000  229778.000000
# mean        3.375843          8.740179       2.088603    1101.692176
# std         0.921576          8.670772       2.991486     792.916449
# min         1.000000        -15.000000       0.000000       0.000000
# 25%         3.000000          1.000000       0.000000     360.000000
# 50%         4.000000          9.000000       1.000000    1059.000000
# 75%         4.000000         15.000000       3.000000    1653.000000
# max         4.261005         38.000000      32.000000    3768.120000
#
#             fat_100g  saturated-fat_100g  trans-fat_100g  carbohydrates_100g  \
# count  229778.000000       229778.000000   229778.000000       229778.000000
# mean       12.509243            4.467391        0.044343           31.191181
# std        17.266904            7.438411        0.438545           28.841313
# min         0.000000            0.000000        0.000000            0.000000
# 25%         0.030000            0.000000        0.000000            5.420000
# 50%         4.929600            1.100000        0.000000           20.000000
# 75%        20.000000            6.250000        0.000000           57.140000
# max       100.000000          100.000000       35.710000          100.000000
#
#          sugars_100g     fiber_100g  proteins_100g      salt_100g  \
# count  229778.000000  229778.000000  229778.000000  229778.000000
# mean       14.874612       2.123711       6.952508       1.540680
# std        20.592091       4.114854       8.012196       6.160844
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.900000       0.000000       0.700000       0.052500
# 50%         4.800000       0.300000       4.620000       0.535000
# 75%        21.430000       2.900000      10.000000       1.322500
# max       100.000000     100.000000     100.000000     100.000000
#
#          sodium_100g   alcohol_100g  fruits-vegetables-nuts_100g
# count  229778.000000  229778.000000                229778.000000
# mean        0.612333       0.011066                     0.692974
# std         2.460901       0.532077                     7.204513
# min         0.000000       0.000000                     0.000000
# 25%         0.021000       0.000000                     0.000000
# 50%         0.214000       0.000000                     0.000000
# 75%         0.528864       0.000000                     0.000000
# max        49.987200     100.000000                   100.000000

# %%
df_ex= df_final.loc[(df_final['fat_100g'] < (df_final['saturated-fat_100g'] + df_final['trans-fat_100g'])) |
                       (df_final['carbohydrates_100g'] < df_final['sugars_100g']) | 
                    ((df_final['fat_100g'] + df_final['carbohydrates_100g'] + df_final['proteins_100g'])>100)]
df_ex.shape
# Out:
# (4516, 20)

# %%
df_final.drop(df_ex.index, axis=0, inplace = True)

# %%
df_final[['nova_group','nutriscore_score']] = df_final[['nova_group','nutriscore_score']].astype('int')

# %%
df_final.rename(columns={
      "code": "Code",
      "product_name": "Nom du produit",
      "nova_group" : "Groupe NOVA",
      "nutriscore_score" : "Nutrition Score",
      "additives_n": "Additifs",
      "nutriscore_grade": "Nutri-Score",
      "energy_100g": "Energie",
      "fat_100g": "Lipides",
      "saturated-fat_100g": "Graisses saturées", 
      "trans-fat_100g": "Acides gras",
      "carbohydrates_100g": "Glucides",
      "sugars_100g" : "Sucres",
      "fiber_100g" : "Fibres",
      "proteins_100g" : "Protéïnes",
      "salt_100g" : "Sel",
      "sodium_100g" : "Sodium",
      "alcohol_100g" : "Alcool",
      "fruits-vegetables-nuts_100g" : "Fruits-Légumes-Noix",
      "ingredients_text" : "Ingrédients",
      "url" : "URL"}, inplace=True)

# %%
df_final.dtypes
# Out:
# Code                    object
# Nom du produit          object
# Groupe NOVA              int32
# Nutrition Score          int32
# Additifs               float64
# Nutri-Score             object
# Energie                float64
# Lipides                float64
# Graisses saturées      float64
# Acides gras            float64
# Glucides               float64
# Sucres                 float64
# Fibres                 float64
# Protéïnes              float64
# Sel                    float64
# Sodium                 float64
# Alcool                 float64
# Fruits-Légumes-Noix    float64
# Ingrédients             object
# URL                     object
# dtype: object

# %%
df_final.describe()
# Out:
#          Groupe NOVA  Nutrition Score       Additifs        Energie  \
# count  225262.000000    225262.000000  225262.000000  225262.000000
# mean        3.309635         8.686445       2.088355    1104.618632
# std         0.970504         8.678662       2.995015     791.754106
# min         1.000000       -15.000000       0.000000       0.000000
# 25%         3.000000         1.000000       0.000000     364.000000
# 50%         4.000000         9.000000       1.000000    1070.000000
# 75%         4.000000        15.000000       3.000000    1657.000000
# max         4.000000        38.000000      32.000000    3768.120000
#
#              Lipides  Graisses saturées    Acides gras       Glucides  \
# count  225262.000000      225262.000000  225262.000000  225262.000000
# mean       12.590000           4.487718       0.043133      31.202548
# std        17.172475           7.403496       0.422135      28.771703
# min         0.000000           0.000000       0.000000       0.000000
# 25%         0.100000           0.000000       0.000000       5.490000
# 50%         5.000000           1.110000       0.000000      20.000000
# 75%        20.000000           6.340000       0.000000      57.140000
# max       100.000000         100.000000      35.710000     100.000000
#
#               Sucres         Fibres      Protéïnes            Sel  \
# count  225262.000000  225262.000000  225262.000000  225262.000000
# mean       14.722362       2.152407       7.022210       1.517335
# std        20.433544       4.097068       8.001416       6.101547
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.900000       0.000000       0.740000       0.060000
# 50%         4.761905       0.400000       4.710000       0.543560
# 75%        21.428571       3.000000      10.000000       1.320000
# max       100.000000     100.000000     100.000000     100.000000
#
#               Sodium         Alcool  Fruits-Légumes-Noix
# count  225262.000000  225262.000000        225262.000000
# mean        0.602921       0.010505             0.703879
# std         2.437065       0.519225             7.260478
# min         0.000000       0.000000             0.000000
# 25%         0.024000       0.000000             0.000000
# 50%         0.217000       0.000000             0.000000
# 75%         0.528000       0.000000             0.000000
# max        49.987200     100.000000           100.000000

# %%
visu(df_final)
# Out:
#                        Code Nom du produit Groupe NOVA Nutrition Score  \
# Valeurs manquantes        0              0           0               0
# Nombre de valeurs    225262         225262      225262          225262
# Taux de remplissage   100.0          100.0       100.0           100.0
# Valeurs différentes  225167         175241           4              54
#
#                     Additifs Nutri-Score Energie Lipides Graisses saturées  \
# Valeurs manquantes         0           0       0       0                 0
# Nombre de valeurs     225262      225262  225262  225262            225262
# Taux de remplissage    100.0       100.0   100.0   100.0             100.0
# Valeurs différentes       33           5    3628    4996              3782
#
#                     Acides gras Glucides  Sucres  Fibres Protéïnes     Sel  \
# Valeurs manquantes            0        0       0       0         0       0
# Nombre de valeurs        225262   225262  225262  225262    225262  225262
# Taux de remplissage       100.0    100.0   100.0   100.0     100.0   100.0
# Valeurs différentes        1007     7811    6325    1466      3680   10463
#
#                      Sodium  Alcool Fruits-Légumes-Noix Ingrédients     URL
# Valeurs manquantes        0       0                   0           0       0
# Nombre de valeurs    225262  225262              225262      225262  225262
# Taux de remplissage   100.0   100.0               100.0       100.0   100.0
# Valeurs différentes   10355      78                 734      179222  225261

# %%
df_final.to_csv("./Data/DonnéesNettoyées.csv")
